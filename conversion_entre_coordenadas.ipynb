# %% [markdown]
# <a href="https://colab.research.google.com/github/vi0908/MC/blob/main/conversion_entre_coordenadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
EPS = 23.43927944 # en grados
EPS_R = math.radians(EPS) # en radianes

# %% [markdown]
# # ***HELIOCÉNTRICAS ☀***

# %% [markdown]
# *COORDENADAS HELIOCÉNTRICAS:*
#
#
# ---
#
# CARTESIANAS
# *   Eclípticas: $x,y,z$
# *   Ecuatoriales: $x',y',z'$
#
# ESFÉRICAS
#
#
# *   Eclípticas:
#
#
# 1.   longitud eclíptica: $\lambda$
# 2.   latitud eclíptica: $\beta$
# 3. radio vector: $r$

# %% [markdown]
# ![CARTESIANAS_ECLIPTICAS_HELIOCENTRICAS.png](data:image/png;base64,...)

# %% [markdown]
# ![ESFERICAS_ECLIPTICAS_HELIOCENTRICAS.png](data:image/png;base64,...)

# %% [markdown]
# ## **CONVERSIONES ENTRE PLANOS**

# %% [markdown]
# ## **DEL PLANO DE LA ECLÍPTICA AL PLANO ECUATORIAL**

# %% [markdown]
# ![Captura de pantalla 2023-05-09 a la(s) 10.10.18 a.m..png](data:image/png;base64,...)

# %%
# DE ECLÍPTICAS A ECUATORIALES (HELIOCÉNTRICAS)

# Introduce las coordenadas ECLÍPTICAS:
x =
y =
z =


x_ = x
y_ = y * math.cos(EPS_R) - z * math.sin(EPS_R)
z_ = y * math.sin(EPS_R) + z * math.cos(EPS_R)
r_ = math.sqrt(x_**2 + y_**2 + z_**2)

print('\n---> x_ = {} u.a \n---> y_ = {} u.a \n---> z_ = {} u.a \n---> r_ = {} u.a (calculado por componentes)'.format(x_,y_,z_,r_))

# %% [markdown]
# ## **DEL PLANO ECUATORIAL AL PLANO DE LA ECLÍPTICA**

# %% [markdown]
# ![Captura de pantalla 2023-05-09 a la(s) 10.21.31 a.m..png](data:image/png;base64,...)

# %%
# DE ECUATORIALES A ECLÍPTICAS (HELIOCÉNTRICAS)

# Introduce las coordenadas ECUATORIALES :
x_ =
y_ =
z_ =

x = x_
y = y_ * math.cos(EPS_R) + z_ * math.sin(EPS_R)
z = - y_ * math.sin(EPS_R) + z_ * math.cos(EPS_R)
r = math.sqrt(x**2 + y**2 + z**2)

print('\n---> x = {} u.a \n---> y = {} u.a \n---> z = {} u.a \n---> r = {} u.a (calculado por componentes)'.format(x,y,z,r))

# %% [markdown]
# ## **CONVERSIONES ENTRE CARTESIANAS Y ESFÉRICAS**

# %% [markdown]
# ## **DE CARTESIANAS A ESFÉRICAS**

# %% [markdown]
# ![Captura de pantalla 2023-05-09 a la(s) 10.41.19 a.m..png](data:image/png;base64,...)

# %%
# CONVERSIÓN DE COORDENADAS CARTESIANAS A ESFÉRICAS ECLÍPTICAS (HELIOCÉNTRICAS)

# Introduce las coordenadas CARTESIANAS:
x =
y =
z =

r = math.sqrt(x**2 + y**2 + z**2)
lamb = math.degrees(math.atan2(y, x))
beta = math.degrees(math.asin(z/r))

print('---> Longitud eclíptica: lambda = {}º \n---> Latitud eclíptica: beta = {}º \n---> Radio vector: r = {} u.a'.format(lamb, beta, r))

# %% [markdown]
# ## **DE ESFÉRICAS  A CARTESIANAS ECLÍPTICAS HELIOCÉNTRICAS**

# %% [markdown]
# ![Captura de pantalla 2023-06-13 a la(s) 6.14.43 p.m..png](data:image/png;base64,...)

# %%
# CONVERSIÓN DE COORDENADAS ESFÉRICAS ECLÍPTICAS A CARTESIANAS (HELIOCÉNTRICAS)

# Introduce las coordenadas ESFÉRICAS ECLÍPTICAS:

lamb =   # en grados (LONGITUD)
lamb_r = math.radians(lamb) # CONVERSIÓN A RADIANES
beta = # en grados (LATITUD)
beta_r = math.radians(beta) # CONVERSIÓN A RADIANES
r =

x = r * math.cos(lamb_r) * math.cos(beta_r)
y = r * math.sin(lamb_r) * math.cos(beta_r)
z = r * math.sin(beta_r)

print('\n---> x = {} u.a \n---> y = {} u.a \n---> z = {} u.a \n---> r = {} u.a (por valor dado)'.format(x,y,z,r))

# %% [markdown]
# # ***GEOCÉNTRICAS***

# %% [markdown]
# *COORDENADAS GEOCÉNTRICAS*
#
#
# ---
#
#
# CARTESIANAS
# *   Eclípticas: $\xi,\eta,\zeta$
# *   Ecuatoriales: $\xi',\eta',\zeta'$
#
# ESFÉRICAS
#
#
# *   Ecuatoriales:
#
#
# 1.   ascención recta: $\alpha$
# 2.   declinación: $\delta$
# 3.   distancia geocéntrica: $\rho$
#
# *   Eclípticas:
#
#
# 1.   longitud eclíptica geocéntrica: $\lambda_{g}$
# 2.   latitud eclíptica geocéntrica: $\beta_{g}$
# 3.   distancia geocéntrica: $r_{g}$

# %% [markdown]
# ![Captura de pantalla 2023-05-09 a la(s) 9.23.05 a.m..png](data:image/png;base64,...)

# %% [markdown]
# ## **CONVERSIONES ENTRE PLANOS**

# %% [markdown]
# ### **DE ECLÍPTICAS A ECUATORIALES CARTESIANAS**

# %% [markdown]
# ![Captura de pantalla 2023-06-13 a la(s) 6.27.22 p.m..png](data:image/png;base64,...)

# %%
# DE ECLÍPTICAS A ECUATORIALES (GEOCÉNTRICAS)

# Introduce las coordenadas ECLÍPTICAS:
xi =
eta =
zeta =


xi_ = xi
eta_ = eta * math.cos(EPS_R) - zeta * math.sin(EPS_R)
zeta_ = eta * math.sin(EPS_R) + zeta * math.cos(EPS_R)
rho_ = math.sqrt(xi_**2 + eta_**2 + zeta_**2)



print('\n---> xi_ = {} u.a \n---> eta_ = {} u.a \n---> zeta_ = {} u.a \n---> rho_ = {} u.a (calculado por componentes)'.format(xi_,eta_,zeta_,rho_))

# %% [markdown]
# ### **DE ECUATORIALES A ECLÍPTICAS CARTESIANAS**

# %% [markdown]
# ![Captura de pantalla 2023-06-13 a la(s) 6.27.29 p.m..png](data:image/png;base64,...)

# %%
# DE ECUATORIALES A ECLÍPTICAS (GEOCÉNTRICAS)

# Introduce las coordenadas ECUATORIALES:

xi_ =
eta_ =
zeta_ =


xi = xi_
eta = eta_ * math.cos(EPS_R) + zeta_ * math.sin(EPS_R)
zeta = - eta_ * math.sin(EPS_R) + zeta_ * math.cos(EPS_R)
rho = math.sqrt(xi**2 + eta**2 + zeta**2)

print('\n---> xi = {} u.a \n---> eta = {} u.a \n---> zeta = {} u.a \n---> rho = {} u.a (calculado por componentes)'.format(xi,eta,zeta,rho))

# %% [markdown]
# ## **CONVERSIONES ENTRE CARTESIANAS Y ESFÉRICAS**

# %% [markdown]
# ## **DE CARTESIANAS A ESFÉRICAS ECUATORIALES**

# %% [markdown]
# Se le debe aplicar el criterio del cuadrante a $α$

# %% [markdown]
# ![Captura de pantalla 2023-05-09 a la(s) 10.42.51 a.m..png](data:image/png;base64,...)

# %%
# COORDENADAS CARTESIANAS A ESFÉRICAS ECUATORIALES

# Introduce las coordenadas CARTESIANAS:

xi_ =
eta_ =
zeta_ =

rho = math.sqrt(xi_**2 + eta_**2 + zeta_ **2 )
alpha = math.degrees(math.atan2(eta_, xi_))
delta = math.degrees(math.asin((zeta_) / rho))
alpha = alpha / 15
print('\n---> distancia geocéntrica: rho = {} u.a \n--->  ascención recta: alpha = {}º (convertido a horas) \n---> delta = {}º'.format(rho,alpha,delta))

# %% [markdown]
# ## **DE ESFÉRICAS A CARTESIANAS ECUATORIALES**

# %% [markdown]
# ![Captura de pantalla 2023-05-09 a la(s) 11.07.59 a.m..png](data:image/png;base64,...)

# %%
# DE COORDENADAS ESFÉRICAS A CARTESIANAS ECUATORIALES

# Introduce las coordenadas ESFÉRICAS:

rho = # en u.a
alpha =   # en horas
delta =  # en grados

alphar = math.radians(alpha) * 15 # en radianes
deltar = math.radians(delta) # en radianes

xi_ = rho * math.cos(alphar) * math.cos(deltar)
eta_ = rho * math.sin(alphar) * math.cos(deltar)
zeta_ = rho * math.sin(deltar)

print('\n---> xi_ = {} u.a \n---> eta_ = {} u.a \n---> zeta_ = {} u.a'.format(xi_,eta_,zeta_))

# %% [markdown]
# ## **DE CARTESIANAS A ESFÉRICAS ECLÍPTICAS**

# %% [markdown]
# Se le debe aplicar el criterio del cuadrante a $\lambda_g$

# %% [markdown]
# ![Captura de pantalla 2023-06-13 a la(s) 8.09.10 p.m..png](data:image/png;base64,...)

# %%
# DE COORDENADAS CARTESIANAS A ESFÉRICAS ECLÍPTICAS (GEOCÉNTRICAS)

# Introduce las coordenadas CARTESIANAS:

xi =
eta =
zeta =

rho_g = math.sqrt(xi**2 + eta**2 + zeta**2 )
lambda_g = math.degrees(math.atan2(eta, xi))
beta_g = math.degrees(math.asin(zeta / rho_g))
print('\n---> Distancia geocéntrica: rho = {} u.a \n---> Longitud eclíptica geocéntrica: lambda = {}º \n---> Latitud eclíptica geocéntrica: beta = {}º'.format(rho_g,lambda_g,beta_g))

# %% [markdown]
# ## **DE ESFÉRICAS A CARTESIANAS ECLÍPTICAS**

# %% [markdown]
# ![Captura de pantalla 2023-06-13 a la(s) 8.09.05 p.m..png](data:image/png;base64,...)

# %%
# DE ESFÉRICAS CARTESIANAS A ECLÍPTICAS (GEOCÉNTRICAS)

# Introduce las coordenadas CARTESIANAS:

r_g = # en u.a
lambda_g =  # en horas
beta_g =  # en grados

lambda_r = math.radians(lambda_g) * 15 # en radianes
beta_r = math.radians(beta_g) # en radianes

xi_ = r_g * math.cos(lambda_r) * math.cos(beta_r)
eta_ = r_g * math.sin(lambda_r) * math.cos(beta_r)
zeta_ = r_g * math.sin(beta_r)

print('\n---> xi = {} u.a \n---> eta = {} u.a \n---> zeta = {} u.a'.format(xi,eta,zeta))
